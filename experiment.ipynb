# %%
from src.experiment import ExperimentLauncher

# %%
config_path = 'configuration/SOCO23Config/'
experiment_launcher = ExperimentLauncher(config_path, save_file='results/TimeSelection/results.csv')

# %%
experiment_launcher.run()
# Out:
#         loss  mean_squared_error  mean_absolute_error  \
# 0   0.495238            0.495238             0.585586
# 1   0.753065            0.753065             0.750870
# 2   0.409178            0.409178             0.516383
# 3   0.424811            0.424811             0.526136
# 4   0.495238            0.495238             0.585586
# ..       ...                 ...                  ...
# 0   1.071389            1.071389             0.552216
# 0   1.071389            1.071389             0.552216
# 0   0.933037            0.933037             0.497688
# 0   0.933037            0.933037             0.497688
# 0   0.933037            0.933037             0.497688
#
#     mean_absolute_percentage_error   dataset dataset_name  \
# 0                        95.969727  TorneoCO     TorneoCO
# 1                       110.110321  TorneoCO     TorneoCO
# 2                       531.921814  TorneoCO     TorneoCO
# 3                       208.870331  TorneoCO     TorneoCO
# ...
