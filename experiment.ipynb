# %%
from src.experiment import ExperimentLauncher

# %%
config_path = 'configuration/SOCO23Config/'
experiment_launcher = ExperimentLauncher(config_path, save_file='results/TimeSelection/results_fixed.csv')

# %%
experiment_launcher.run()
# Out:
#         loss  mean_squared_error  mean_absolute_error  \
# 0   0.589298            0.589298             0.651064
# 1   0.432555            0.432555             0.512339
# 2   0.286092            0.286092             0.373427
# 3   0.335659            0.335659             0.379901
# 4   0.382067            0.382067             0.375785
# ..       ...                 ...                  ...
# 0   0.121552            0.121498             0.216762
# 0   0.082142            0.081887             0.186152
# 0   0.158855            0.157459             0.295283
# 0   0.194672            0.192519             0.326067
# 0   0.139636            0.127545             0.253525
#
#     mean_absolute_percentage_error   dataset dataset_name  \
# 0                       109.618553  TorneoCO     TorneoCO
# 1                       551.194702  TorneoCO     TorneoCO
# 2                        78.343925  TorneoCO     TorneoCO
# 3                        76.505844  TorneoCO     TorneoCO
# 4                        86.000740  TorneoCO     TorneoCO
# ..                             ...       ...          ...
# 0                        28.297522   Traffic      Traffic
# 0                        24.006901   Traffic      Traffic
# 0                        32.658112   Traffic      Traffic
# 0                        39.636150   Traffic      Traffic
# 0                        29.491852   Traffic      Traffic
#
#     dataset_params_seq_len  dataset_params_pred_len  \
# 0                       12                        1
# 1                       24                        1
# 2                       12                        1
# 3                       12                        1
# 4                       12                        1
# ..                     ...                      ...
# 0                        6                        1
# 0                        6                        1
# 0                        6                        1
# 0                        6                        1
# 0                        6                        1
#
#     dataset_params_select_timesteps  dataset_params_shift  ... model_name  \
# 0                              True                   144  ...      dense
# 1                              True                   144  ...      dense
# 2                              True                   144  ...      dense
# 3                              True                   144  ...      dense
# 4                              True                   144  ...      dense
# ..                              ...                   ...  ...        ...
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
#
#    model_params_keep_dims model_params_type  \
# 0                   False        tensorflow
# 1                   False        tensorflow
# 2                   False        tensorflow
# 3                   False        tensorflow
# 4                   False        tensorflow
# ..                    ...               ...
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
#
#                                              features  \
# 0   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# 1   ['target t-24', 'dd t-24', 'no2 t-24', 'o3 t-2...
# 2   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# 3   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# 4   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# ..                                                ...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
#
#                                     selected_features   duration  \
# 0   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...  11.763290
# 1   ['target t-24', 'dd t-24', 'no2 t-24', 'o3 t-2...   4.416993
# 2   ['target t-7', 'target t-2', 'target t-6', 'ta...  17.350155
# 3   ['target t-7', 'target t-2', 'target t-6', 'ta...  16.657084
# 4   ['target t-12', 'target t-7', 'target t-2', 't...  16.751693
# ..                                                ...        ...
# 0   [target_2 t-6, target_7 t-6, target_19 t-6, ta...  41.545078
# 0   [target_4 t-6, target_5 t-6, target_11 t-6, ta...  24.455041
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...  16.906876
# 0   [target_13 t-6, target_49 t-6, target_65 t-6, ...  56.117329
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...  16.753149
#
#                                               history  \
# 0   [0.5038579106330872, 0.38416558504104614, 0.31...
# 1   [0.7577648162841797, 0.686423122882843, 0.3751...
# 2   [0.32696667313575745, 0.21756196022033691, 0.1...
# 3   [0.356266587972641, 0.2252076268196106, 0.1789...
# 4   [0.34760382771492004, 0.25365057587623596, 0.2...
# ..                                                ...
# 0   [7.912792205810547, 7.668704986572266, 5.40967...
# 0   [7.913822174072266, 7.691165924072266, 5.27672...
# 0   [7.9146728515625, 7.649794101715088, 5.3448734...
# 0   [7.925325393676758, 7.505867958068848, 4.64358...
# 0   [7.964088439941406, 7.351752758026123, 4.21927...
#
#                                 code selection_params_threshold  \
# 0   77950229aec3b3347c5eca61dbc5155f                        NaN
# 1   a802384ad059d66689a43320ff9abfd0                        NaN
# 2   ba9f83e67a9206ec392ce76517a270a1                       0.50
# 3   dc3ee899adad55d737d432261bebd494                       0.55
# 4   19de536b06eb09d0b826edcef806fe7b                       0.60
# ..                               ...                        ...
# 0   202be12bcbab30d4dbfaea77a65898f3                        NaN
# 0   b327f36309b65db98a18907ffe359a8e                        NaN
# 0   e8ba56f87fd2d0a09ff2a8801028d3e7                        NaN
# 0   aa20b607d4bbde702a5efc6a85641108                        NaN
# 0   3154f47309e9fd163adedfcbd3b5e5dd                        NaN
#
#    selection_params_regularization
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 0                           0.0001
# 0                           0.0005
# 0                           0.0010
# 0                           0.0050
# 0                           0.0100
#
# [888 rows x 22 columns]
#         loss  mean_squared_error  mean_absolute_error  \
# 0   0.589298            0.589298             0.651064
# 1   0.432555            0.432555             0.512339
# 2   0.286092            0.286092             0.373427
# 3   0.335659            0.335659             0.379901
# 4   0.382067            0.382067             0.375785
# ..       ...                 ...                  ...
# 0   0.121552            0.121498             0.216762
# 0   0.082142            0.081887             0.186152
# 0   0.158855            0.157459             0.295283
# 0   0.194672            0.192519             0.326067
# 0   0.139636            0.127545             0.253525
#
#     mean_absolute_percentage_error   dataset dataset_name  \
# 0                       109.618553  TorneoCO     TorneoCO
# 1                       551.194702  TorneoCO     TorneoCO
# 2                        78.343925  TorneoCO     TorneoCO
# 3                        76.505844  TorneoCO     TorneoCO
# 4                        86.000740  TorneoCO     TorneoCO
# ..                             ...       ...          ...
# 0                        28.297522   Traffic      Traffic
# 0                        24.006901   Traffic      Traffic
# 0                        32.658112   Traffic      Traffic
# 0                        39.636150   Traffic      Traffic
# 0                        29.491852   Traffic      Traffic
#
#     dataset_params_seq_len  dataset_params_pred_len  \
# 0                       12                        1
# 1                       24                        1
# 2                       12                        1
# 3                       12                        1
# 4                       12                        1
# ..                     ...                      ...
# 0                        6                        1
# 0                        6                        1
# 0                        6                        1
# 0                        6                        1
# 0                        6                        1
#
#     dataset_params_select_timesteps  dataset_params_shift  ... model_name  \
# 0                              True                   144  ...      dense
# 1                              True                   144  ...      dense
# 2                              True                   144  ...      dense
# 3                              True                   144  ...      dense
# 4                              True                   144  ...      dense
# ..                              ...                   ...  ...        ...
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
# 0                              True                    24  ...      dense
#
#    model_params_keep_dims model_params_type  \
# 0                   False        tensorflow
# 1                   False        tensorflow
# 2                   False        tensorflow
# 3                   False        tensorflow
# 4                   False        tensorflow
# ..                    ...               ...
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
# 0                   False        tensorflow
#
#                                              features  \
# 0   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# 1   ['target t-24', 'dd t-24', 'no2 t-24', 'o3 t-2...
# 2   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# 3   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# 4   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...
# ..                                                ...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...
#
#                                     selected_features   duration  \
# 0   ['target t-12', 'dd t-12', 'no2 t-12', 'o3 t-1...  11.763290
# 1   ['target t-24', 'dd t-24', 'no2 t-24', 'o3 t-2...   4.416993
# 2   ['target t-7', 'target t-2', 'target t-6', 'ta...  17.350155
# 3   ['target t-7', 'target t-2', 'target t-6', 'ta...  16.657084
# 4   ['target t-12', 'target t-7', 'target t-2', 't...  16.751693
# ..                                                ...        ...
# 0   [target_2 t-6, target_7 t-6, target_19 t-6, ta...  41.545078
# 0   [target_4 t-6, target_5 t-6, target_11 t-6, ta...  24.455041
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...  16.906876
# 0   [target_13 t-6, target_49 t-6, target_65 t-6, ...  56.117329
# 0   [target_0 t-6, target_1 t-6, target_2 t-6, tar...  16.753149
#
#                                               history  \
# 0   [0.5038579106330872, 0.38416558504104614, 0.31...
# 1   [0.7577648162841797, 0.686423122882843, 0.3751...
# 2   [0.32696667313575745, 0.21756196022033691, 0.1...
# 3   [0.356266587972641, 0.2252076268196106, 0.1789...
# 4   [0.34760382771492004, 0.25365057587623596, 0.2...
# ..                                                ...
# 0   [7.912792205810547, 7.668704986572266, 5.40967...
# 0   [7.913822174072266, 7.691165924072266, 5.27672...
# 0   [7.9146728515625, 7.649794101715088, 5.3448734...
# 0   [7.925325393676758, 7.505867958068848, 4.64358...
# 0   [7.964088439941406, 7.351752758026123, 4.21927...
#
#                                 code selection_params_threshold  \
# 0   77950229aec3b3347c5eca61dbc5155f                        NaN
# 1   a802384ad059d66689a43320ff9abfd0                        NaN
# 2   ba9f83e67a9206ec392ce76517a270a1                       0.50
# 3   dc3ee899adad55d737d432261bebd494                       0.55
# 4   19de536b06eb09d0b826edcef806fe7b                       0.60
# ..                               ...                        ...
# 0   202be12bcbab30d4dbfaea77a65898f3                        NaN
# 0   b327f36309b65db98a18907ffe359a8e                        NaN
# 0   e8ba56f87fd2d0a09ff2a8801028d3e7                        NaN
# 0   aa20b607d4bbde702a5efc6a85641108                        NaN
# 0   3154f47309e9fd163adedfcbd3b5e5dd                        NaN
#
#    selection_params_regularization
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ..                             ...
# 0                           0.0001
# 0                           0.0005
# 0                           0.0010
# 0                           0.0050
# 0                           0.0100
#
# [888 rows x 22 columns]
